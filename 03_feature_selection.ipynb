# %% [markdown]
# # Feature Selection

# %%
# !pip install boruta
# Out:
# Requirement already satisfied: boruta in /home/rachtrx/mambaforge/envs/sc1015/lib/python3.10/site-packages (0.3)
# Requirement already satisfied: numpy>=1.10.4 in /home/rachtrx/.local/lib/python3.10/site-packages (from boruta) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in /home/rachtrx/mambaforge/envs/sc1015/lib/python3.10/site-packages (from boruta) (1.4.1.post1)
# Requirement already satisfied: scipy>=0.17.0 in /home/rachtrx/mambaforge/envs/sc1015/lib/python3.10/site-packages (from boruta) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/rachtrx/mambaforge/envs/sc1015/lib/python3.10/site-packages (from scikit-learn>=0.17.1->boruta) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/rachtrx/mambaforge/envs/sc1015/lib/python3.10/site-packages (from scikit-learn>=0.17.1->boruta) (3.3.0)

# %%
import pandas as pd
import numpy as np
import pickle
import json
from sklearn.impute import SimpleImputer
from constants.constants import *
from models import Boruta, PreProcessor # see models.py for implementation

pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', 20) # show all rows
pd.set_option('display.max_seq_items', None)

# %% [markdown]
# To keep it simple for now, we will just use the outcome to filter out the most important features. We should only use the data from 2019 to 2022 as we are predicting 2023

# %%
dfs = []

for year in range(2019, 2023):
    df = pd.read_csv(f'./data/machine_learning/outcome/{str(year)}.csv')
    dfs.append(df)

train_df = pd.concat(dfs, ignore_index=True)

# %%
train_df = train_df.drop(['form', 'opponent_form'], axis=1) # too complicated to take into account form when predicting

# %% [markdown]
# We create a Preprocessor class and Boruta child class in models.py so that it can have access to the preprocessor
#
# Normalize the data

# %%
train_df_clean = train_df.dropna()
X = train_df_clean.drop(columns=['outcome'])
y = train_df_clean['outcome']
preprocessor = PreProcessor(X, y)

# %%
with open('data/machine_learning/pkl/processor.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)

# %% [markdown]
# ## Using Correlation Matrix to drop Highly Related Cols

# %%
# Calculate the correlation matrix
corr_matrix = preprocessor.df_train_preprocessed.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find index of feature columns with correlation greater than 0.85
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]

CORR_COLS = list(set(preprocessor.df_train_preprocessed.columns) - set(to_drop))
print(f"{len(CORR_COLS)} features left")
# Out:
# 155 features left

# %%
with open(UNIQUE_FEATURES_PATH, 'w') as file:
    json.dump(CORR_COLS, file, indent=4)

# %% [markdown]
# # Logistic Regression
#
# Trying to use Logistic Regression to further reduce the number of features

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(solver='lbfgs', multi_class='multinomial', max_iter=1000)
# Fit your logistic regression model
log_reg.fit(preprocessor.df_train_preprocessed[CORR_COLS], preprocessor.y_train_encoded)
# Out:
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
feature_names = preprocessor.df_train_preprocessed[CORR_COLS].columns
coefficients = log_reg.coef_
class_labels = preprocessor.target_encoder.inverse_transform(log_reg.classes_)

coef_df = pd.DataFrame(coefficients.T,  # Transpose to make features as rows
                       columns=[f'Coeff_Class_{cls}' for cls in class_labels],
                       index=feature_names)

coef_df
# Out:
#                                                Coeff_Class_D  Coeff_Class_L  \
# team_corner_kicks_in_per90                         -0.051626      -0.034214
# team_carries_into_penalty_area_per90               -0.001666      -0.082413
# team_cards_yellow_per90                            -0.016557       0.027901
# opponent_sca_take_ons_per90                        -0.060198       0.059999
# opponent_tackles_def_3rd_per90                      0.039956      -0.012848
# ...                                                      ...            ...
# team_players_used                                  -0.009566       0.035006
# opponent_take_ons_tackled_pct                      -0.004822      -0.008110
# opponent_challenge_tackles_per90                    0.078559      -0.055045
# opponent_tackles_interceptions_per90                0.015652      -0.001766
# opponent_gk_psnpxg_per_shot_on_target_against      -0.048497      -0.015441
#
#                                                Coeff_Class_W
# team_corner_kicks_in_per90                          0.085840
# team_carries_into_penalty_area_per90                0.084079
# team_cards_yellow_per90                            -0.011344
# opponent_sca_take_ons_per90                         0.000200
# opponent_tackles_def_3rd_per90                     -0.027108
# ...                                                      ...
# team_players_used                                  -0.025440
# opponent_take_ons_tackled_pct                       0.012931
# opponent_challenge_tackles_per90                   -0.023514
# opponent_tackles_interceptions_per90               -0.013886
# opponent_gk_psnpxg_per_shot_on_target_against       0.063938
#
# [155 rows x 3 columns]

# %%
top_features_d = coef_df.nlargest(20, 'Coeff_Class_D', keep='all').index
top_features_l = coef_df.nlargest(5, 'Coeff_Class_L', keep='all').index
top_features_w = coef_df.nlargest(5, 'Coeff_Class_W', keep='all').index

top_features_all = top_features_d.union(top_features_l).union(top_features_w)
coef_df.loc[top_features_all, :]
# Out:
#                                   Coeff_Class_D  Coeff_Class_L  Coeff_Class_W
# is_home                               -0.001118      -0.360220       0.361337
# opponent_aerials_lost_per90            0.041067      -0.058209       0.017142
# opponent_assisted_shots_per90          0.071048       0.019760      -0.090808
# opponent_assists_per90                 0.014598      -0.238126       0.223528
# opponent_challenge_tackles_per90       0.078559      -0.055045      -0.023514
# ...                                         ...            ...            ...
# team_tackles_def_3rd_per90             0.069956      -0.052033      -0.017923
# team_tackles_interceptions_per90       0.035033      -0.031884      -0.003148
# team_take_ons_per90                    0.038815       0.025862      -0.064676
# team_throw_ins_per90                   0.038624      -0.222169       0.183545
# team_touches_def_pen_area_per90        0.049731       0.042662      -0.092393
#
# [27 rows x 3 columns]

# %%
LOG_REG_COLS = top_features_all.tolist()

# %% [markdown]
# ## Boruta Algorithm
#
# <br>
# Referred to https://www.sciencedirect.com/science/article/pii/S1877050922007955 by Fátima Rodriguesa
# and Ângelo Pintob
#
# - Boruta algorithm was used. Boruta is a heuristic variable selection algorithm based on the random forests algorithm that aims to find the most relevant variables in a dataset.
# - The Boruta algorithm show the relevant and non-relevant variables. This algorithm was used because it does not look for a suboptimal solution, instead it tries to find all variables with relevant information, thus allowing to eliminate variables that would negatively affect the forecast models

# %%
boruta = Boruta()

boruta.fit(preprocessor.df_train_preprocessed[LOG_REG_COLS], preprocessor.y_train)
BORUTA_FEATURES = boruta.get_selected_features()

with open(BORUTA_FEATURES_PATH, 'w') as file:
    json.dump(BORUTA_FEATURES, file, indent=4)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	9 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	10 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	11 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	12 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	13 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	14 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	15 / 100
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	4
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	19 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	20 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	21 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	22 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	23 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	24 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	25 / 100
# Confirmed: 	19
# Tentative: 	4
# Rejected: 	4
# Iteration: 	26 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	27 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	28 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	29 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	30 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	31 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	32 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	33 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	34 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	35 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	36 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	37 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	41 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	42 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	43 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	44 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	45 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	46 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	51 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	52 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	53 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	54 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	55 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	56 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	57 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	58 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	59 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	60 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	61 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	62 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	66 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	67 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	68 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	69 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	70 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	71 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	72 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	73 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	74 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	75 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	76 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	77 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	84 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	85 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	86 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	87 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	88 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	89 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	90 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	91 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	92 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	93 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	94 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	95 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	96 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	97 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	4

# %%
print(BORUTA_FEATURES)
# Out:
# ['is_home', 'opponent_aerials_lost_per90', 'opponent_assisted_shots_per90', 'opponent_assists_per90', 'opponent_offsides_per90', 'opponent_passes_dead_per90', 'opponent_squad_value', 'opponent_tackles_def_3rd_per90', 'opponent_throw_ins_per90', 'opponent_touches_def_pen_area_per90', 'team_aerials_lost_per90', 'team_assists_per90', 'team_corner_kicks_per90', 'team_passes_dead_per90', 'team_squad_value', 'team_tackles_def_3rd_per90', 'team_tackles_interceptions_per90', 'team_take_ons_per90', 'team_throw_ins_per90', 'team_touches_def_pen_area_per90']
